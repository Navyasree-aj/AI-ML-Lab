# %%
import heapq

# %%
graph = {
        'A': [(1, 'B'), (4, 'C')],
        'B': [(2, 'C'), (5, 'D'), (12, 'E')],
        'C': [(2, 'D')],
        'D': [(3, 'E')],
        'E': []
}

heuristics = {
    'A': 7,
    'B': 6,
    'C': 4,
    'D': 2,
    'E': 0
}

visited_costs = {}

priority_queue = []
